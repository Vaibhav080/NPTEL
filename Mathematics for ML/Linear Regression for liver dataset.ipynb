# %%
#importig librariries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from ucimlrepo import fetch_ucirepo

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# fetch dataset
liver_disorders = fetch_ucirepo(id = 60)

# %%
#data
X = liver_disorders.data.features
y = liver_disorders.data.targets

# %%
#Extracting Independent variable
x = X['sgpt']
#Extracting Dependent variable
y = X['sgot']

# %%
#Splitting the dataset into training and test set.

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2)

x_test_array = x_test.to_numpy() # Convert series to numpy array
x_test_array = x_test_array.reshape(-1,1) # Reshape the array
y_test_array = y_test.to_numpy() # Covert series to numpy array
y_test_array = y_test_array.reshape(-1,1) # Reshape the array

# %%
x_train_array = x_train.to_numpy() # Convert series to numpy array
x_train_array = x_train_array.reshape(-1,1) # Reshape
