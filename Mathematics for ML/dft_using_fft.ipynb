# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Given data points
f = np.array([1.3,2.7,1.4,0.44,0.45])

# %%
# Calculate DFT
F = np.fft.fft(f)
F
# Out:
# array([ 6.29      +0.j        ,  0.78481226-2.704151j  ,
#        -0.67981226-0.40950256j, -0.67981226+0.40950256j,
#         0.78481226+2.704151j  ])

# %%
# Frequency components
frequencies = np.fft.fftfreq(len(f))
frequencies
# Out:
# array([ 0. ,  0.2,  0.4, -0.4, -0.2])

# %%
# Plot the original data points
plt.figure(figsize = (12,6))

plt.subplot(1,2,1)

plt.stem(f)
plt.title("Original Data")

plt.xlabel("Sample index")
plt.ylabel("Amplitude")

#Plot the DFT
plt.subplot(1,2,2)
plt.stem(frequencies, np.abs(F))
plt.title("DFT Magnitude")

plt.xlabel("Frequency Index")
plt.ylabel("Magnitude")

plt.tight_layout()
plt.show()
